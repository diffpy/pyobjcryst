# %% [markdown]
# ## Creating a crystal from a CIF & display it in 3D
# In this short example you can open a CIF file directly from a filename or an URL, and display it in 3D.
#
# You can also play with the spacegroup and see how that changes the crystal structure.
#
# *Note: this requires installing `ipywidgets` and `py3Dmol` (as of 2021/05 the conda-forge version is obsolete, so just install using pip). Otherwise You will just get a warning message*

# %%
from pyobjcryst.crystal import *
from pyobjcryst.atom import Atom
from pyobjcryst.scatteringpower import ScatteringPowerAtom
from math import pi

# %% [markdown]
# ### From IUCr journals

# %%
c = create_crystal_from_cif("http://scripts.iucr.org/cgi-bin/sendcif?dt3034sup1",
                            oneScatteringPowerPerElement=True,
                            connectAtoms=True)
print(c.GetFormula())
c.widget_3d()
# Out:
# C15 Cl1 H14 N1 O1 S1
# <div id="3dmolviewer_1623527600490104"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_1623527600490104" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_1623527600490104 = null;
# var warn = document.getElementById("3dmolwarning_1623527600490104");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1623527600490104 = $3Dmol.createViewer($("#3dmolviewer_1623527600490104"),{backgroundColor:"white"});
# viewer_1623527600490104.zoomTo();
# 	viewer_1623527600490104.removeAllModels();
# 	viewer_1623527600490104.addModel();
# 		viewer_1623527600490104.getModel().addAtoms([{"elem": "C", "x": 2.525626303866482, "y": -10.583993045327068, "z": 8.564552709595139, "bonds": [1, 2, 3], "bondOrder": [1, 1, 1]}, {"elem": "N", "x": 2.679006435471862, "y": -11.826809786555172, "z": 9.11589267111316, "bonds": [0, 4, 5], "bondOrder": [1, 1, 1]}, {"elem": "C", "x": 2.051726291260734, "y": -10.414518082398176, "z": 7.2462267600552375, "bonds": [0, 9, 10], "bondOrder": [1, 1, 1]}, {"elem": "C", "x": 2.83326637620826, "y": -9.4128371789217, "z": 9.30320533715098, "bonds": [0, 13, 18], "bondOrder": [1, 1, 1]}, {"elem": "C", "x": 3.0697373993489516, "y": -11.969433680695296, "z": 10.509773414596772, "bonds": [1, 6, 7, 8], "bondOrder": [1, 1, 1, 1]}, {"elem": "C", "x": 2.3564625531146755, "y": -13.01313452705741, "z": 8.355202707428486, "bonds": [1, 15, 16, 17], "bondOrder": [1, 1, 1, 1]}, {"elem": "H", "x": 3.9526932018774104, "y": -11.612176349651813, "z": 10.632235028443578, "bonds": [4], "bondOrder": [1]}, {"elem": "H", "x": 3.0642321127288477, "y": -12.898930967250466, "z": 10.74976415193441, "bonds": [4], "bondOrder": [1]}, {"elem": "H", "x": 2.4513067361588576, "y": -11.491869801825285, "z": 11.066674468145601, "bonds": [4], "bondOrder": [1]}, {"elem": "C", "x": 1.8990042450448563, "y": -9.151998744598032, "z": 6.709997632231097, "bonds": [2, 11, 12], "bondOrder": [1, 1, 1]}, {"elem": "H", "x": 1.8397571195864468, "y": -11.16059160990715, "z": 6.7338188210729975, "bonds": [2], "bondOrder": [1]}, {"elem": "C", "x": 2.2159958691245154, "y": -7.984678745162488, "z": 7.428292947636817, "bonds": [9, 13, 14], "bondOrder": [1, 1, 1]}, {"elem": "H", "x": 1.5751759898249793, "y": -9.070051386094093, "z": 5.841852434184844, "bonds": [9], "bondOrder": [1]}, {"elem": "C", "x": 2.687980004002614, "y": -8.163220633417367, "z": 8.741371793246177, "bonds": [3, 11, 19], "bondOrder": [1, 1, 1]}, {"elem": "C", "x": 2.0138127263808587, "y": -6.684498593169451, "z": 6.830990632413711, "bonds": [11, 20, 21], "bondOrder": [1, 1, 1]}, {"elem": "H", "x": 1.4129074108013204, "y": -13.033185791569949, "z": 8.178803317034976, "bonds": [5], "bondOrder": [1]}, {"elem": "H", "x": 2.6047203126714953, "y": -13.7933821893543, "z": 8.857746916647388, "bonds": [5], "bondOrder": [1]}, {"elem": "H", "x": 2.8368086114650564, "y": -13.001801519930364, "z": 7.523995519839034, "bonds": [5], "bondOrder": [1]}, {"elem": "H", "x": 3.1376722660565597, "y": -9.490251334574818, "z": 10.178906264781325, "bonds": [3], "bondOrder": [1]}, {"elem": "H", "x": 2.9089793767213603, "y": -7.413659387254716, "z": 9.246014468752714, "bonds": [13], "bondOrder": [1]}, {"elem": "C", "x": 2.221344988523783, "y": -5.4735888656795035, "z": 7.398280814140667, "bonds": [14, 22, 23], "bondOrder": [1, 1, 1]}, {"elem": "H", "x": 1.704423949827821, "y": -6.679616202753783, "z": 5.954135079219439, "bonds": [14], "bondOrder": [1]}, {"elem": "H", "x": 2.5802058190703008, "y": -5.425990235745908, "z": 8.255407656859655, "bonds": [20], "bondOrder": [1]}, {"elem": "C", "x": 1.8910856133606808, "y": -4.237921116292477, "z": 6.686596762121027, "bonds": [20, 24, 25], "bondOrder": [1, 1, 1]}, {"elem": "O", "x": 1.5174258342057414, "y": -4.203572907346487, "z": 5.505214032972673, "bonds": [23], "bondOrder": [1]}, {"elem": "C", "x": 1.9884520523691558, "y": -2.977494305759669, "z": 7.4440330084798365, "bonds": [23, 26, 27], "bondOrder": [1, 1, 1]}, {"elem": "S", "x": 1.6461376107150334, "y": -1.5128956554114823, "z": 6.587641098067249, "bonds": [25, 28], "bondOrder": [1, 1]}, {"elem": "C", "x": 2.3137749530792955, "y": -2.7299078512966637, "z": 8.756272467574144, "bonds": [25, 29, 30], "bondOrder": [1, 1, 1]}, {"elem": "C", "x": 1.9479578878548194, "y": -0.5938599659442906, "z": 7.999466073838777, "bonds": [26, 30, 32], "bondOrder": [1, 1, 1]}, {"elem": "H", "x": 2.5319275875818272, "y": -3.396474695885182, "z": 9.366692229886453, "bonds": [27], "bondOrder": [1]}, {"elem": "C", "x": 2.2815320826128254, "y": -1.3505691646993168, "z": 9.080213740 ...
# Box(children=(VBox(children=(HBox(children=(VBox(children=(FloatRangeSlider(value=(0.0, 1.0), description='Xra…

# %% [markdown]
# ### From the Crystallography Open Database

# %%
c1 = create_crystal_from_cif("http://crystallography.net/cod/4506702.cif",
                            oneScatteringPowerPerElement=True,
                            connectAtoms=True)
print(c1.GetFormula())
c1.widget_3d()
# Out:
# C29 H32 N4 O5
# <div id="3dmolviewer_1623527600770262"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_1623527600770262" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_1623527600770262 = null;
# var warn = document.getElementById("3dmolwarning_1623527600770262");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1623527600770262 = $3Dmol.createViewer($("#3dmolviewer_1623527600770262"),{backgroundColor:"white"});
# viewer_1623527600770262.zoomTo();
# 	viewer_1623527600770262.removeAllModels();
# 	viewer_1623527600770262.addModel();
# 		viewer_1623527600770262.getModel().addAtoms([{"elem": "C", "x": 3.98052745213745, "y": 5.927395158052582, "z": 4.473051034885408, "bonds": [1, 2, 3], "bondOrder": [1, 1, 1]}, {"elem": "C", "x": 3.8786116346765804, "y": 4.536097925466148, "z": 4.362985739406698, "bonds": [0, 4, 5], "bondOrder": [1, 1, 1]}, {"elem": "C", "x": 2.975767619388009, "y": 6.721801170514135, "z": 3.9153396644705425, "bonds": [0, 6, 7], "bondOrder": [1, 1, 1]}, {"elem": "N", "x": 5.138416643148265, "y": 6.43607416641739, "z": 5.130033939784634, "bonds": [0, 13, 14], "bondOrder": [1, 1, 1]}, {"elem": "H", "x":
"bondOrder": [1, 1, 1]}, {"elem": "H", "x": 10.285182263192137, "y": 6.645317886603371, "z": 2.871637321815614, "bonds": [27], "bondOrder": [1]}, {"elem": "C", "x": 10.874668943725647, "y": 4.739518970109909, "z": 3.116479242816747, "bonds": [25, 27, 31], "bondOrder": [1, 1, 1]}, {"elem": "H", "x": 11.795652262536281, "y": 2.99128467201958, "z": 3.630022409495238, "bonds": [25], "bondOrder": [1]}, {"e ...
# Box(children=(VBox(children=(HBox(children=(VBox(children=(FloatRangeSlider(value=(0.0, 1.0), description='Xra…

# %% [markdown]
# ### Create a Crystal structure and change the spacegroup

# %%
c = Crystal(5, 5, 5, pi/2, pi/2, pi/2, "P1")
cu = ScatteringPowerAtom("Cu", "Cu")
c.AddScatterer(Atom(0,0,0, "Cu", cu))
c.widget_3d(extra_opacity=0.1, extra_dist=2)
# Out:
# <div id="3dmolviewer_1623527600817823"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_1623527600817823" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_1623527600817823 = null;
# var warn = document.getElementById("3dmolwarning_1623527600817823");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1623527600817823 = $3Dmol.createViewer($("#3dmolviewer_1623527600817823"),{backgroundColor:"white"});
# viewer_1623527600817823.zoomTo();
# 	viewer_1623527600817823.removeAllModels();
# 	viewer_1623527600817823.addModel();
# 		viewer_1623527600817823.getModel().addAtoms([{"elem": "Cu", "x": 0.0, "y": 0.0, "z": 0.0}, {"elem": "Cu", "x": 3.061616997868383e-16, "y": -3.061616997868383e-16, "z": 5.0}, {"elem": "Cu", "x": 3.061616997868383e-16, "y": 5.0, "z": 0.0}, {"elem": "Cu", "x": 6.123233995736766e-16, "y": 5.0, "z": 5.0}, {"elem": "Cu", "x": 5.0, "y": 0.0, "z": 0.0}, {"elem": "Cu", "x": 5.0, "y": -3.061616997868383e-16, "z": 5.0}, {"elem": "Cu", "x": 5.0, "y": 5.0, "z": 0.0}, {"elem": "Cu", "x": 5.0, "y": 5.0, "z": 5.0}]);
# 		viewer_1623527600817823.getModel().setStyle({"stick": {"radius": 0.2, "opacity": 0.5}, "sphere": {"scale": 0.3, "colorscheme": "jmol", "opacity": 0.5}});
# 	viewer_1623527600817823.addModel();
# 		viewer_1623527600817823.getModel().addAtoms([{"elem": "Cu", "x": 0.0, "y": 0.0, "z": 0.0}, {"elem": "Cu", "x": 3.061616997868383e-16, "y": -3.061616997868383e-16, "z": 5.0}, {"elem": "Cu", "x": 3.061616997868383e-16, "y": 5.0, "z": 0.0}, {"elem": "Cu", "x": 6.123233995736766e-16, "y": 5.0, "z": 5.0}, {"elem": "Cu", "x": 5.0, "y": 0.0, "z": 0.0}, {"elem": "Cu", "x": 5.0, "y": -3.061616997868383e-16, "z": 5.0}, {"elem": "Cu", "x": 5.0, "y": 5.0, "z": 0.0}, {"elem": "Cu", "x": 5.0, "y": 5.0, "z": 5.0}]);
# 		viewer_1623527600817823.getModel().setStyle({"stick": {"radius": 0.2, "opacity": 0.1}, "sphere": {"scale": 0.3, "colorscheme": "jmol", "opacity": 0.1}});
# 	viewer_1623527600817823.addModel();
# 		viewer_1623527600817823.getModel().setCrystData(5.0,5.0,5.0,90.0,90.0,90.0);
# 	viewer_1623527600817823.addUnitCell({"box": {"color": "purple"}, "alabel": "X", "blabel": "Y", "clabel": "Z", "alabelstyle": {"fontColor": "black", "backgroundColor": "white", "inFront": true, "fontSize": 40}, "astyle": {"color": "darkred", "radius": 5, "midpos": -10}});
# 		viewer_1623527600817823.getModel().addAtoms([{"elem": "Cu", "x": 0.0, "y": 0.0, "z": 0.0}, {"elem": "Cu", "x": 3.061616997868383e-16, "y": -3.061616997868383e-16, "z": 5.0}, {"elem": "Cu", "x": 3.061616997868383e-16, "y": 5.0, "z": 0.0}, {"elem": "Cu", "x": 6.123233995736766e-16, "y": 5.0, "z": 5.0}, {"elem": "Cu", "x": 5.0, "y": 0.0, "z": 0.0}, {"elem": "Cu", "x": 5.0, "y": -3.061616997868383e-16, "z": 5.0}, {"elem": "Cu", "x": 5.0, "y": 5.0, "z": 0.0}, {"elem": "Cu", "x": 5.0, "y": 5.0, "z": 5.0}]);
# 		viewer_1623527600817823.getModel().setStyle({"stick": {"radius": 0.2, "opacity": 1}, "sphere": {"scale": 0.3, "colorscheme": "jmol", "opacity": 1}});
# 	viewer_1623527600817823.zoomTo();
# viewer_1623527600817823.render();
# });
# </script>
# Box(children=(VBox(children=(HBox(children=(VBox(children=(FloatRangeSlider(value=(0.0, 1.0), description='Xra…

# %%
# Change the spacegroup and update the display
c.GetSpaceGroup().ChangeSpaceGroup("Fm-3m")
#c.GetSpaceGroup().ChangeSpaceGroup("Ia-3d")
c.UpdateDisplay()
# Out:
# <script>
#             $3Dmolpromise.then(function() { //wrap in promise for non-interactive functionality
#                 	viewer_1623527600817823.removeAllModels();
# 	viewer_1623527600817823.addModel();
# 		viewer_1623527600817823.getModel().addAtoms([{"elem": "Cu", "x": 0.0, "y": 0.0, "z": 0.0}, {"elem": "Cu", "x": 3.061616997868383e-16, "y": -3.061616997868383e-16, "z": 5.0}, {"elem": "Cu", "x": 3.061616997868383e-16, "y": 5.0, "z": 0.0}, {"elem": "Cu", "x": 6.123233995736766e-16, "y": 5.0, "z": 5.0}, {"elem": "Cu", "x": 5.0, "y": 0.0, "z": 0.0}, {"elem": "Cu", "x": 5.0, "y": -3.061616997868383e-16, "z": 5.0}, {"elem": "Cu", "x": 5.0, "y": 5.0, "z": 0.0}, {"elem": "Cu", "x": 5.0, "y": 5.0, "z": 5.0}, {"elem": "Cu", "x": 0.0, "y": 0.0, "z": 0.0}, {"elem": "Cu", "x": 3.061616997868383e-16, "y": -3.061616997868383e-16, "z": 5.0}, {"elem": "Cu", "x": 3.061616997868383e-16, "y": 5.0, "z": 0.0}, {"elem": "Cu", "x": 6.123233995736766e-16, "y": 5.0, "z": 5.0}, {"elem": "Cu", "x": 5.0, "y": 0.0, "z": 0.0}, {"elem": "Cu", "x": 5.0, "y": -3.061616997868383e-16, "z": 5.0}, {"elem": "Cu", "x": 5.0, "y": 5.0, "z": 0.0}, {"elem": "Cu", "x": 5.0, "y": 5.0, "z": 5.0}, {"elem": "Cu", "x": 0.0, "y": 0.0, "z": 0.0}, {"elem": "Cu", "x": 3.061616997868383e-16, "y": -3.061616997868383e-16, "z": 5.0}, {"elem": "Cu", "x": 3.061616997868383e-16, "y": 5.0, "z": 0.0}, {"elem": "Cu", "x": 6.123233995736766e-16, "y": 5.0, "z": 5.0}, {"elem": "Cu", "x": 5.0, "y": 0.0, "z": 0.0}, {"elem": "Cu", "x": 5.0, "y": -3.061616997868383e-16, "z": 5.0}, {"elem": "Cu", "x": 5.0, "y": 5.0, "z": 0.0}, {"elem": "Cu", "x": 5.0, "y": 5.0, "z": 5.0}, {"elem": "Cu", "x": 0.0, "y": 0.0, "z": 0.0}, {"elem": "Cu", "x": 3.061616997868383e-16, "y": -3.061616997868383e-16, "z": 5.0}, {"elem": "Cu", "x": 3.061616997868383e-16, "y": 5.0, "z": 0.0}, {"elem": "Cu", "x": 6.123233995736766e-16, "y": 5.0, "z": 5.0}, {"elem": "Cu", "x": 5.0, "y": 0.0, "z": 0.0}, {"elem": "Cu", "x": 5.0, "y": -3.061616997868383e-16, "z": 5.0}, {"elem": "Cu", "x": 5.0, "y": 5.0, "z": 0.0}, {"elem": "Cu", "x": 5.0, "y": 5.0, "z": 5.0}, {"elem": "Cu", "x": 0.0, "y": 0.0, "z": 0.0}, {"elem": "Cu", "x": 3.061616997868383e-16, "y": -3.061616997868383e-16, "z": 5.0}, {"elem": "Cu", "x": 3.061616997868383e-16, "y": 5.0, "z": 0.0}, {"elem": "Cu", "x": 6.123233995736766e-16, "y": 5.0, "z": 5.0}, {"elem": "Cu", "x": 5.0, "y": 0.0, "z": 0.0}, {"elem": "Cu", "x": 5.0, "y": -3.061616997868383e-16, "z": 5.0}, {"elem": "Cu", "x": 5.0, "y": 5.0, "z": 0.0}, {"elem": "Cu", "x": 5.0, "y": 5.0, "z": 5.0}, {"elem": "Cu", "x": 0.0, "y": 0.0, "z": 0.0}, {"elem": "Cu", "x": 3.061616997868383e-16, "y": -3.061616997868383e-16, "z": 5.0}, {"elem": "Cu", "x": 3.061616997868383e-16, "y": 5.0, "z": 0.0}, {"elem": "Cu", "x": 6.123233995736766e-16, "y": 5.0, "z": 5.0}, {"elem": "Cu", "x": 5.0, "y": 0.0, "z": 0.0}, {"elem": "Cu", "x": 5.0, "y": -3.061616997868383e-16, "z": 5.0}, {"elem": "Cu", "x": 5.0, "y": 5.0, "z": 0.0}, {"elem": "Cu", "x": 5.0, "y": 5.0, "z": 5.0}, {"elem": "Cu", "x": 0.0, "y": 0.0, "z": 0.0}, {"elem": "Cu", "x": 3.061616997868383e-16, "y": -3.061616997868383e-16, "z": 5.0}, {"elem": "Cu", "x": 3.061616997868383e-16, "y": 5.0, "z": 0.0}, {"elem": "Cu", "x": 6.123233995736766e-16, "y": 5.0, "z": 5.0}, {"elem": "Cu", "x": 5.0, "y": 0.0, "z": 0.0}, {"elem": "Cu", "x": 5.0, "y": -3.061616997868383e-16, "z": 5.0}, {"elem": "Cu", "x": 5.0, "y": 5.0, "z": 0.0}, {"elem": "Cu", "x": 5.0, "y": 5.0, "z": 5.0}, {"elem": "Cu", "x": 0.0, "y": 0.0, "z": 0.0}, {"elem": "Cu", "x": 3.061616997868383e-16, "y": -3.061616997868383e-16, "z": 5.0}, {"elem": "Cu", "x": 3.061616997868383e-16, "y": 5.0, "z": 0.0}, {"elem": "Cu", "x": 6.123233995736766e-16, "y": 5.0, "z": 5.0}, {"elem": "Cu", "x": 5.0, "y": 0.0, "z": 0.0}, {"elem": "Cu", "x": 5.0, "y": -3.061616997868383e-16, "z": 5.0}, {"elem": "Cu", "x": 5.0, "y": 5.0, "z": 0.0}, {"elem": "Cu", "x": 5.0, "y": 5.0, "z": 5.0}, {"elem": "Cu", "x": 0.0, "y": 0.0, "z": 0.0}, {"elem": "Cu", "x": 3.061616997868383e-16, "y": -3.061616997868383e-16, "z": 5.0}, {"elem": "Cu", "x": 3.061616997868383e-16, "y": 5.0, "z": 0.0}, {"elem": "Cu", "x": 6.123233995736766e-16, "y": 5.0, "z": 5.0}, {"elem": "Cu", " ...
