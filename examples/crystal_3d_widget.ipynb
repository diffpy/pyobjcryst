# %% [markdown]
# ## Creating a crystal from a CIF & display it in 3D
# In this short example you can open a CIF file directly from a filename or an URL, and display it in 3D.
#
# *Note: this requires installing `ipywidgets` and `py3Dmol` (as of 2021/05 the conda-forge version is obsolete, so just install using pip). Otherwise You will just get a warning message*

# %%
from pyobjcryst.crystal import *

# %% [markdown]
# ### From IUCr journals

# %%
c = create_crystal_from_cif("http://scripts.iucr.org/cgi-bin/sendcif?dt3034sup1")
print(c.GetFormula())
c.widget_3d()
# Out:
# C15 Cl1 H14 N1 O1 S1
# <div id="3dmolviewer_1622403484635529"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_1622403484635529" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_1622403484635529 = null;
# var warn = document.getElementById("3dmolwarning_1622403484635529");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1622403484635529 = $3Dmol.createViewer($("#3dmolviewer_1622403484635529"),{backgroundColor:"white"});
# viewer_1622403484635529.zoomTo();
# 	viewer_1622403484635529.removeAllModels();
# 	viewer_1622403484635529.addModel("data_crystal_for3d\n\n_computing_structure_solution     'FOX http://objcryst.sourceforge.net'\n\n_cell_length_a          7.453\n_cell_length_b         17.436\n_cell_length_c         10.708\n_cell_length_alpha     90.000\n_cell_length_beta     101.479\n_cell_length_gamma     90.000\nloop_\n    _atom_site_label\n    _atom_site_type_symbol\n    _atom_site_fract_x\n    _atom_site_fract_y\n    _atom_site_fract_z\n    _atom_site_occupancy\n              S1    S   0.4003   0.9132   0.6278 1.0000\n              S1    S   0.0997   0.4132   0.8722 1.0000\n              S1    S   0.5997   0.0868   0.3722 1.0000\n              S1    S   0.9003   0.5868   0.1278 1.0000\n             Cl1   Cl   0.4636   0.0641   0.7579 1.0000\n             Cl1   Cl   0.0364   0.5641   0.7421 1.0000\n             Cl1   Cl   0.5364   0.9359   0.2421 1.0000\n             Cl1   Cl   0.9636   0.4359   0.2579 1.0000\n              O1    O   0.3536   0.7589   0.5246 1.0000\n              O1    O   0.1464   0.2589   0.9754 1.0000\n              O1    O   0.6464   0.2411   0.4754 1.0000\n              O1    O   0.8536   0.7411   0.0246 1.0000\n             C11    C   0.5722   0.3930   0.8162 1.0000\n             C11    C   0.9278   0.8930   0.6838 1.0000\n             C11    C   0.4278   0.6070   0.1838 1.0000\n             C11    C   0.0722   0.1070   0.3162 1.0000\n              C8    C   0.4997   0.5421   0.7079 1.0000\n              C8    C   0.0003   0.0421   0.7921 1.0000\n              C8    C   0.5003   0.4579   0.2921 1.0000\n              C8    C   0.9997   0.9579   0.2079 1.0000\n              C4    C   0.4696   0.8292   0.7094 1.0000\n              C4    C   0.0304   0.3292   0.7906 1.0000\n              C4    C   0.5304   0.1708   0.2906 1.0000\n              C4    C   0.9696   0.6708   0.2094 1.0000\n              C3    C   0.5490   0.8434   0.8344 1.0000\n              C3    C   0.9510   0.3434   0.6656 1.0000\n              C3    C   0.4510   0.1566   0.1656 1.0000\n              C3    C   0.0490   0.6566   0.3344 1.0000\n              H3    H   0.5949   0.8052   0.8926 1.0000\n              H3    H   0.9051   0.3052   0.6074 1.0000\n              H3    H   0.4051   0.1948   0.1074 1.0000\n              H3    H   0.0949   0.6948   0.3926 1.0000\n              C2    C   0.5535   0.9225   0.8653 1.0000\n              C2    C   0.9465   0.4225   0.6347 1.0000\n              C2    C   0.4465   0.0775   0.1347 1.0000\n              C2    C   0.0535   0.5775   0.3653 1.0000\n              H2    H   0.6011   0.9423   0.9457 1.0000\n              H2    H   0.8989   0.4423   0.5543 1.0000\n              H2    H   0.3989   0.0577   0.0543 1.0000\n              H2    H   0.1011   0.5577   0.4457 1.0000\n              C6    C   0.4996   0.6861   0.7050 1.0000\n              C6    C   0.0004   0.1861   0.7950 1.0000\n              C6    C   0.5004   0.3139   0.2950 1.0000\n              C6    C   0.9996   0.8139   0.2050 1.0000\n              H6    H   0.5711   0.6888   0.7867 1.0000\n              H6    H   0.9289   0.1888   0.7133 1.0000\n              H6    H   0.4289   0.3112   0.2133 1.0000\n              H6    H   0.0711   0.8112   0.2867 1.0000\n             C13    C   0.4376   0.4751   0.6394 1.0000\n             C13    C   0.0624   0.9751   0.8606 1.0000\n             C13    C   0.5624   0.5249   0.3606 1.0000\n             C13    C   0.9376   0.0249   0.1394 1.0000\n             H13    H   0.3705   0.4798   0.5567 1.0000\n             H13    H   0.1295   0.9798   0.9433 1.0000\n             H13    H   0.6295   0.5202   0.4433 1.0000\n             H13    H   0.8705   0.0202   0.0567 1.0000\n              C1    C   0.4793   0.9659   0.7623 1.0000\n              C1    C   0.0207   0.4659   0.7377 1.0000\n              C1    C   0.5207   0.0341   0.2377 1.0000\n              C1    C   0.9793   0.5341   0.2623 1.0000\n              N1    N   0.6078   0.3217   0.8687 1.0000\n              N1    N   0.8922   0.8217   0.6313 1 ...
# Box(children=(VBox(children=(HBox(children=(VBox(children=(FloatRangeSlider(value=(0.0, 1.0), description='Xra…

# %% [markdown]
# ### From the Crystallography Open Database

# %%
c1 = create_crystal_from_cif("http://crystallography.net/cod/4506702.cif")
print(c1.GetFormula())
c1.widget_3d()
# Out:
# C29 H32 N4 O5
# <div id="3dmolviewer_1622403485056035"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_1622403485056035" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_1622403485056035 = null;
# var warn = document.getElementById("3dmolwarning_1622403485056035");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1622403485056035 = $3Dmol.createViewer($("#3dmolviewer_1622403485056035"),{backgroundColor:"white"});
# viewer_1622403485056035.zoomTo();
# 	viewer_1622403485056035.removeAllModels();
# 	viewer_1622403485056035.addModel("data_crystal_for3d\n\n_computing_structure_solution     'FOX http://objcryst.sourceforge.net'\n\n_cell_length_a          9.055\n_cell_length_b         10.624\n_cell_length_c         14.316\n_cell_length_alpha     82.970\n_cell_length_beta      89.690\n_cell_length_gamma     73.850\nloop_\n    _atom_site_label\n    _atom_site_type_symbol\n    _atom_site_fract_x\n    _atom_site_fract_y\n    _atom_site_fract_z\n    _atom_site_occupancy\n              H1    H   0.5039   0.0823   0.8210 1.0000\n              H1    H   0.4961   0.9177   0.1790 1.0000\n              H2    H   0.0220   0.8537   0.5987 1.0000\n              H2    H   0.9780   0.1463   0.4013 1.0000\n              H3    H   0.8849   0.4369   0.1525 1.0000\n              H3    H   0.1151   0.5631   0.8475 1.0000\n              H4    H   0.4725   0.5043   0.3734 1.0000\n              H4    H   0.5275   0.4957   0.6266 1.0000\n              H5    H   0.2140   0.9438   0.4008 1.0000\n              H5    H   0.7860   0.0562   0.5992 1.0000\n              H6    H   0.5949   0.6219   0.4443 1.0000\n              H6    H   0.4051   0.3781   0.5557 1.0000\n              H7    H   0.5552   0.7655   0.3865 1.0000\n              H7    H   0.4448   0.2345   0.6135 1.0000\n              H8    H   0.4865   0.7365   0.4902 1.0000\n              H8    H   0.5135   0.2635   0.5098 1.0000\n             H10    H   0.0567   0.0696   0.6119 1.0000\n             H10    H   0.9433   0.9304   0.3881 1.0000\n             H11    H   0.3790   0.7379   0.7320 1.0000\n             H11    H   0.6210   0.2621   0.2680 1.0000\n             H12    H   0.1722   0.1969   0.6846 1.0000\n             H12    H   0.8278   0.8031   0.3154 1.0000\n             H13    H   0.4892   0.8731   0.8016 1.0000\n             H13    H   0.5108   0.1269   0.1984 1.0000\n             H14    H   0.0557   0.5634   0.5886 1.0000\n             H14    H   0.9443   0.4366   0.4114 1.0000\n             H15    H   0.9769   0.6965   0.5344 1.0000\n             H15    H   0.0231   0.3035   0.4656 1.0000\n             H16    H   0.1159   0.5973   0.4914 1.0000\n             H16    H   0.8841   0.4027   0.5086 1.0000\n             H17    H   0.8042   0.0373   0.7811 1.0000\n             H17    H   0.1958   0.9627   0.2189 1.0000\n             H18    H   0.6113   0.9228   0.0080 1.0000\n             H18    H   0.3887   0.0772   0.9920 1.0000\n             H19    H   0.0460   0.9353   0.8431 1.0000\n             H19    H   0.9540   0.0647   0.1569 1.0000\n             H20    H   0.8504   0.8110   0.0822 1.0000\n             H20    H   0.1496   0.1890   0.9178 1.0000\n             H21    H   0.3958   0.0519   0.3976 1.0000\n             H21    H   0.6042   0.9481   0.6024 1.0000\n             H22    H   0.1258   0.7515   0.0827 1.0000\n             H22    H   0.8742   0.2485   0.9173 1.0000\n             H23    H   0.2611   0.7903   0.9071 1.0000\n             H23    H   0.7389   0.2097   0.0929 1.0000\n             H24    H   0.3617   0.0045   0.5005 1.0000\n             H24    H   0.6383   0.9955   0.4995 1.0000\n             H25    H   0.5315   0.6679   0.8917 1.0000\n             H25    H   0.4685   0.3321   0.1083 1.0000\n             H26    H   0.3618   0.6941   0.1577 1.0000\n             H26    H   0.6382   0.3059   0.8423 1.0000\n             H27    H   0.6008   0.5690   0.2184 1.0000\n             H27    H   0.3992   0.4310   0.7816 1.0000\n             H28    H   0.7685   0.5524   0.9641 1.0000\n             H28    H   0.2315   0.4476   0.0359 1.0000\n             H29    H   0.2946   0.1551   0.4603 1.0000\n             H29    H   0.7054   0.8449   0.5397 1.0000\n             H30    H   0.3966   0.3274   0.3356 1.0000\n             H30    H   0.6034   0.6726   0.6644 1.0000\n             H31    H   0.1093   0.7034   0.2838 1.0000\n             H31    H   0.8907   0.2966   0.7162 1.0000\n             H32    H   0.9333   0.6155   0.2022 1.0000\n             H32    H   0.0667   0.3845   0.7978 1 ...
# Box(children=(VBox(children=(HBox(children=(VBox(children=(FloatRangeSlider(value=(0.0, 1.0), description='Xra…
